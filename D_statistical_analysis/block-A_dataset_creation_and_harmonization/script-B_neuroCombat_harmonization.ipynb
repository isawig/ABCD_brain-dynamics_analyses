# %% [markdown]
# # Code to run ComBat harmonization on fMRI data
# Code by Isabella L.C. Mariani Wigley and Aurora Berto (05 / 2025)
#
# ilmawi@utu.fi; aurber@utu.fi

# %%
import numpy as np
import pandas as pd
import sklearn
import os
import sys
import neuroCombat as nc

from sklearn.impute import SimpleImputer

import warnings
warnings.filterwarnings("ignore")

print(sys.version)
print(np.__version__)
print(pd.__version__)
print(sklearn.__version__)
# Out:
# 3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 08:22:19) [Clang 14.0.6 ]
# 1.26.4
# 2.3.0
# 1.7.0

# %%
# path to the directory containing the data

tabularData_root = r"/path/to/data" # USER.adapt!

# %%
# load the dataset
data_path = os.path.join(tabularData_root, "main_dataset_rsfMRI_FCH_LEiDA_demo.csv") 
data = pd.read_csv(data_path)
data
# Out:
#         src_subject_id              eventname  anthro_1_height_in  \
# 0     NDAR_INV003RTV85  baseline_year_1_arm_1                56.5
# 1     NDAR_INV00BD7VDC  baseline_year_1_arm_1                57.5
# 2     NDAR_INV00CY2MDM  baseline_year_1_arm_1                56.5
# 3     NDAR_INV00HEV6HB  baseline_year_1_arm_1                57.3
# 4     NDAR_INV00LH735Y  baseline_year_1_arm_1                52.0
# ...                ...                    ...                 ...
# 4448  NDAR_INVZZ6ZJ2KY  baseline_year_1_arm_1                57.0
# 4449  NDAR_INVZZ81LEEV  baseline_year_1_arm_1                53.5
# 4450  NDAR_INVZZJ3A7BK  baseline_year_1_arm_1                59.0
# 4451  NDAR_INVZZLZCKAY  baseline_year_1_arm_1                59.5
# 4452  NDAR_INVZZNX6W2P  baseline_year_1_arm_1                56.0
#
#       anthroweight1lb  demo_sex_v2  race_ethnicity           mri_info_visitid  \
# 0                93.0          2.0             1.0  S042_INV003RTV85_baseline
# 1                76.8          1.0             1.0  S090_INV00BD7VDC_baseline
# 2                91.5          1.0             1.0  S021_INV00CY2MDM_baseline
# 3                70.8          1.0             2.0  S012_INV00HEV6HB_baseline
# 4                80.0          1.0             3.0  S011_INV00LH735Y_baseline
# ...               ...          ...             ...                        ...
# 4448            111.0          2.0             1.0  S042_INVZZ6ZJ2KY_baseline
# 4449             57.8          1.0             2.0  S076_INVZZ81LEEV_baseline
# 4450            137.0          2.0             1.0  S042_INVZZJ3A7BK_baseline
# 4451            123.0          2.0             1.0  S042_INVZZLZCKAY_baseline
# 4452             73.0          1.0             1.0  S020_INVZZNX6W2P_baseline
#
#      mri_info_deviceserialnumber  interview_age  rel_family_id  ...  \
# 0                   HASH96a0c182          131.0           8781  ...
# 1                   HASH65b39280          112.0           3810  ...
# 2                   HASHd422be27          130.0           5355  ...
# 3                   HASHe4f6957a          124.0           2257  ...
# 4                   HASH5b0cf1bb          109.0           6069  ...
# ...                          ...            ...            ...  ...
# 4448                HASH96a0c182          124.0           9345  ...
# 4449                HASH03db707f          108.0           8433  ...
# 4450                HASH96a0c182          122.0           9346  ...
# 4451                HASH96a0c182          110.0           9347  ...
# 4452                HASH11ad4ed5          131.0           3797  ...
#
#       Harmonics_energy108  Harmonics_energy109  Harmonics_energy110  \
# 0              158.319426           326.542790           192.675931
# 1              238.030667           506.216418           290.961745
# 2              229.638996           228.446672           486.850276
# 3              234.686758           269.924178           213.925214
# 4              155.455954           280.664438           254.253108
# ...                   ...                  ...                  ...
# 4448           168.400396           229.004979           174.781912
# 4449           323.998671           474.123361           239.067239
# 4450           178.583760           320.437889           171.179551
# 4451           161.903962           421.030194           252.015164
# 4452           211.757970           281.201676           433.081786
#
#       Harmonics_energy111  Harmonics_energy112  Harmonics_energy113  \
# 0              171.474886           350.606622           228.556499
# 1              209.787572           163.663905           348.097102
# 2              488.304623           167.734859           563.542535
# 3              245.301264           287.884664           591.824885
# 4              186.141947           183.348564           204.713464
# ...                   ...                  ...                  ...
# 4448           303.759961           150.655009           233.486270
# 4449           278.370679           824.045017           140.978122
# 4450           157.742490           192.919296           340.688716
# 4451           370.685204           228.116156           328.253479
# 4452           381.094465           112.344809           223.804002
#
#       pubertal_developmental_scale  triponderal_mass_index  birth_weight_g  \
# 0                              3.0               14.272570      3175.14659
# 1                              2.0               11.182072      3628.73896
# 2                              2.0               14.042368      2721.55422
# 3                              2.0               10.416792      2721.55422
# 4                              1.0               15.748694      3175.14659
# ...                            ...                     ...             ...
# 4448                           3.0               16.590635      3628.73896
# 4449                           2.0               10.447950      2721.55422
# 4450                           3.0               18.464142      3628.73896
# 4451                           3.0               16.162882      3175.14659
# 4452                           1.0               11.505974      1814.36948
#
#       batch_id
# 0         S042
# 1         S090
# 2         S021
# 3         S012
# 4         S011
# ...        ...
# 4448      S042
# 4449      S076
# 4450      S042
# 4451      S042
# 4452      S020
#
# [4453 rows x 3867 columns]

# %%
# covariates
num_cov_cols = ["interview_age", "pubertal_developmental_scale", "triponderal_mass_index"] # numeric covariates
cat_cov_cols = ["demo_sex_v2", "race_ethnicity"] # categorical covariates

# %%
# rs-fMRI features
rsfmri_pattern = "^(rsfmri)" # define a pattern to catch all brain imaging features
rsfmri_cols = list(data.filter(regex=rsfmri_pattern).columns) # turn pattern to a list of column names

# %%
# import re

# LEiDA features
leida_pattern = "^(P_k|LT_k|TR_K)"
leida_cols = list(data.filter(regex=leida_pattern).columns)

# %%
# HARMONICS features
harmonics_pattern = "^(Harmonics)"
harmonics_cols = list(data.filter(regex=harmonics_pattern).columns)

# %%
## rs-fMRI harmonization
# imputer model for missing values
imputer = SimpleImputer(strategy="median")

features = imputer.fit_transform(data[rsfmri_cols])

# e.g. demo and ethnicity as covariates
covars = data[num_cov_cols + cat_cov_cols + ["batch_id"]]
categorical_cols = cat_cov_cols
continuous_cols = num_cov_cols
batch_col = "batch_id"

# transpose input data
features = features.T

data_combat = nc.neuroCombat(dat=features,
    covars=covars,

    batch_col=batch_col,
    categorical_cols=categorical_cols,
    continuous_cols=continuous_cols,

    eb=False, 
    parametric=True, 
    mean_only=False, 
    ref_batch=None)["data"]

data_rsfmri_harmonized = data_combat.T
# Out:
# [neuroCombat] Creating design matrix
# [neuroCombat] Standardizing data across features
# [neuroCombat] Fitting L/S model and finding priors
# [neuroCombat] Finding L/S adjustments without Empirical Bayes
# [neuroCombat] Final adjustment of data

# %%
np.isnan(data_combat).any()
# Out:
# False

# %%
import pandas as pd

# Create dataframe with names of original columns
data_rsfmri_harmonized = pd.DataFrame(
    data_rsfmri_harmonized,
    columns=rsfmri_cols,
    index=data.index
)
data_rsfmri_harmonized["src_subject_id"] = data["src_subject_id"].values
data_rsfmri_harmonized
# Out:
#       rsfmri_c_ngd_ad_ngd_ad  rsfmri_c_ngd_ad_ngd_cgc  rsfmri_c_ngd_ad_ngd_ca  \
# 0                   0.457167                 0.241479               -0.078296
# 1                   0.232027                 0.155129               -0.096984
# 2                   0.382290                 0.182702               -0.145126
# 3                   0.226547                 0.187990               -0.077466
# 4                   0.427065                 0.102434               -0.164025
# ...                      ...                      ...                     ...
# 4448                0.323764                 0.210080               -0.141536
# 4449                0.423402                 0.214842               -0.037779
# 4450                0.551212                 0.220227               -0.280502
# 4451                0.304936                 0.166057               -0.010896
# 4452                0.317274                 0.126890               -0.055594
#
#       rsfmri_c_ngd_ad_ngd_dt  rsfmri_c_ngd_ad_ngd_dla  rsfmri_c_ngd_ad_ngd_fo  \
# 0                  -0.119625                 0.023584               -0.033962
# 1                  -0.055408                -0.002533               -0.044779
# 2                  -0.061822                -0.050542               -0.127149
# 3                  -0.061174                 0.049958                0.006558
# 4                  -0.053957                -0.053220               -0.085741
# ...                      ...                      ...                     ...
# 4448               -0.058630                -0.028586                0.041546
# 4449                0.024255                -0.062967                0.018567
# 4450               -0.116360                -0.034828               -0.116768
# 4451               -0.018170                -0.031671               -0.059340
# 4452               -0.047961                -0.009781                0.005726
#
#       rsfmri_c_ngd_ad_ngd_n  rsfmri_c_ngd_ad_ngd_rspltp  \
# 0                 -0.061175                   -0.054620
# 1                 -0.013374                   -0.127971
# 2                 -0.020685                   -0.029186
# 3                 -0.009139                   -0.089641
# 4                  0.018350                    0.013225
# ...                     ...                         ...
# 4448              -0.013603                   -0.112605
# 4449               0.021773                    0.008793
# 4450              -0.015944                    0.056590
# 4451               0.025882                   -0.050387
# 4452               0.014521                   -0.062785
#
#       rsfmri_c_ngd_ad_ngd_sa  rsfmri_c_ngd_ad_ngd_smh  ...  \
# 0                   0.004115                 0.192112  ...
# 1                   0.080834                 0.150156  ...
# 2                  -0.026092                 0.320763  ...
# 3                   0.057503                 0.116328  ...
# 4                  -0.090378                 0.244666  ...
# ...                      ...                      ...  ...
# 4448                0.069620                 0.069825  ...
# 4449                0.166203                -0.014783  ...
# 4450                0.004113                 0.239089  ...
# 4451                0.127491                 0.095790  ...
# 4452               -0.023548                 0.149336  ...
#
#       rsfmri_cor_ngd_vs_scs_hprh  rsfmri_cor_ngd_vs_scs_pllh  \
# 0                       0.104002                    0.011253
# 1                       0.079859                    0.003752
# 2                      -0.063577                   -0.145793
# 3                      -0.014942                   -0.017800
# 4                      -0.081375                    0.054753
# ...                          ...                         ...
# 4448                    0.061826                   -0.060954
# 4449                    0.107647                   -0.049192
# 4450                    0.090404                   -0.027061
# 4451                    0.033272                    0.051310
# 4452                    0.028210                    0.081682
#
#       rsfmri_cor_ngd_vs_scs_plrh  rsfmri_cor_ngd_vs_scs_ptlh  \
# 0                      -0.108310                    0.052413
# 1                       0.055617                    0.125971
# 2                      -0.074672                    0.054565
# 3                      -0.022739                    0.091560
# 4                      -0.095863                    0.035250
# ...                          ...                         ...
# 4448                   -0.037132                    0.009244
# 4449                    0.033706                   -0.047667
# 4450                   -0.000111                    0.239423
# 4451                    0.106973                    0.125450
# 4452                   -0.125097                    0.187390
#
#       rsfmri_cor_ngd_vs_scs_ptrh  rsfmri_cor_ngd_vs_scs_thplh  \
# 0                       0.105932                    -0.150057
# 1                       0.019147                    -0.046688
# 2                       0.218420                    -0.013031
# 3                       0.063601                    -0.068058
# 4                      -0.154294                     0.017505
# ...                          ...                          ...
# 4448                    0.089950                    -0.007309
# 4449                    0.193969                    -0.008287
# 4450                   -0.004772                    -0.092039
# 4451                    0.009328                    -0.108542
# 4452                    0.034216                     0.000394
#
#       rsfmri_cor_ngd_vs_scs_thprh  rsfmri_cor_ngd_vs_scs_vtdclh  \
# 0                       -0.066619                      0.001615
# 1                        0.004899                     -0.039778
# 2                       -0.068786                     -0.071914
# 3                        0.021340                     -0.003984
# 4                        0.060892                      0.016276
# ...                           ...                           ...
# 4448                     0.109443                      0.045622
# 4449                    -0.064136                      0.061139
# 4450                     0.002249                     -0.008852
# 4451                     0.023075                     -0.084718
# 4452                     0.021102                      0.060461
#
#       rsfmri_cor_ngd_vs_scs_vtdcrh    src_subject_id
# 0                         0.101352  NDAR_INV003RTV85
# 1                        -0.038543  NDAR_INV00BD7VDC
# 2                        -0.002755  NDAR_INV00CY2MDM
# 3                        -0.093801  NDAR_INV00HEV6HB
# 4                        -0.260387  NDAR_INV00LH735Y
# ...                            ...               ...
# 4448                     -0.069808  NDAR_INVZZ6ZJ2KY
# 4449                      0.001464  NDAR_INVZZ81LEEV
# 4450                     -0.080285  NDAR_INVZZJ3A7BK
# 4451                     -0.011303  NDAR_INVZZLZCKAY
# 4452                     -0.138833  NDAR_INVZZNX6W2P
#
# [4453 rows x 339 columns]

# %%
# save
data_rsfmri_harmonized.to_csv("dataset_rsfmri_harmonized.csv", index=False)

# %%
## LEiDA harmonization
# imputer model for missing values
imputer = SimpleImputer(strategy="median")

features = imputer.fit_transform(data[leida_cols])

# e.g. demo and ethnicity as covariates
covars = data[num_cov_cols + cat_cov_cols + ["batch_id"]]
categorical_cols = cat_cov_cols
continuous_cols = num_cov_cols
batch_col = "batch_id"

# transpose input data
features = features.T

data_combat = nc.neuroCombat(dat=features,
    covars=covars,

    batch_col=batch_col,
    categorical_cols=categorical_cols,
    continuous_cols=continuous_cols,

    eb=False, 
    parametric=True, 
    mean_only=False, 
    ref_batch=None)["data"]

data_leida_harmonized = data_combat.T
# Out:
# [neuroCombat] Creating design matrix
# [neuroCombat] Standardizing data across features
# [neuroCombat] Fitting L/S model and finding priors
# [neuroCombat] Finding L/S adjustments without Empirical Bayes
# [neuroCombat] Final adjustment of data

# %%
np.isnan(data_combat).any()
# Out:
# False

# %%
import pandas as pd

# Create dataframe with names of original columns
data_leida_harmonized = pd.DataFrame(
    data_leida_harmonized,
    columns=leida_cols,
    index=data.index
)
data_leida_harmonized["src_subject_id"] = data["src_subject_id"].values
data_leida_harmonized
# Out:
#         P_k2c1    P_k2c2    P_k3c1    P_k3c2    P_k3c3    P_k4c1    P_k4c2  \
# 0     0.647172  0.352828  0.562533  0.346135  0.088519  0.374702  0.083642
# 1     0.598438  0.401562  0.517813  0.379745  0.115142  0.394156  0.201396
# 2     0.521013  0.478987  0.346593  0.451067  0.206493  0.267944  0.142255
# 3     0.574936  0.425064  0.487729  0.230851  0.289935  0.373868  0.300234
# 4     0.537369  0.462631  0.393295  0.403082  0.205353  0.282729  0.221302
# ...        ...       ...       ...       ...       ...       ...       ...
# 4448  0.406129  0.593871  0.309663  0.317567  0.374865  0.183703  0.238299
# 4449  0.492747  0.507253  0.390497  0.504162  0.097349  0.327398  0.284921
# 4450  0.589519  0.410481  0.479907  0.151125  0.369604  0.328838  0.174795
# 4451  0.487296  0.512704  0.301820  0.262970  0.437932  0.209052  0.218849
# 4452  0.537912  0.462088  0.389542  0.458896  0.152442  0.300301  0.195868
#
#         P_k4c3    P_k4c4    P_k5c1  ...  TR_K20_C20x12  TR_K20_C20x13  \
# 0     0.441505  0.085085  0.350522  ...      -0.002291      -0.003037
# 1     0.327036  0.072790  0.304260  ...      -0.003160       0.003679
# 2     0.386025  0.203140  0.237144  ...       0.000803       0.000553
# 3     0.160502  0.165179  0.302215  ...      -0.000560       0.005127
# 4     0.265033  0.228642  0.247733  ...      -0.000604       0.001009
# ...        ...       ...       ...  ...            ...            ...
# 4448  0.284686  0.295287  0.191498  ...      -0.002589      -0.004681
# 4449  0.298328  0.083266  0.129863  ...       0.092533       0.003654
# 4450  0.240993  0.250619  0.216742  ...      -0.002695      -0.005042
# 4451  0.222956  0.350473  0.208914  ...      -0.003096       0.101219
# 4452  0.439776  0.079213  0.220968  ...      -0.000329      -0.002867
#
#       TR_K20_C20x14  TR_K20_C20x15  TR_K20_C20x16  TR_K20_C20x17  \
# 0         -0.005565       0.880777      -0.007731      -0.001261
# 1         -0.000671      -0.000847      -0.007886       0.005555
# 2          0.000043      -0.002681      -0.003296      -0.002412
# 3          0.001714      -0.004005      -0.002163      -0.000265
# 4         -0.002796      -0.003525       0.006983      -0.005582
# ...             ...            ...            ...            ...
# 4448       0.107303       0.056160      -0.008438      -0.001241
# 4449       0.114608      -0.001069      -0.000917      -0.004972
# 4450      -0.007438       0.001170      -0.008927      -0.001231
# 4451      -0.011897       0.000791      -0.008658      -0.001219
# 4452       0.001234      -0.007337      -0.002296       0.004230
#
#       TR_K20_C20x18  TR_K20_C20x19  TR_K20_C20x20    src_subject_id
# 0         -0.001492       0.000165      -0.044559  NDAR_INV003RTV85
# 1          0.001750      -0.001430       0.681265  NDAR_INV00BD7VDC
# 2         -0.003751      -0.003269       0.882005  NDAR_INV00CY2MDM
# 3         -0.001367      -0.001254       0.028720  NDAR_INV00HEV6HB
# 4         -0.001689       0.003833       0.016836  NDAR_INV00LH735Y
# ...             ...            ...            ...               ...
# 4448      -0.001558       0.000703       0.781903  NDAR_INVZZ6ZJ2KY
# 4449       0.165557      -0.001961       0.473631  NDAR_INVZZ81LEEV
# 4450      -0.001572       0.000457      -0.044700  NDAR_INVZZJ3A7BK
# 4451      -0.001711       0.003451       0.850299  NDAR_INVZZLZCKAY
# 4452       0.003319       0.633751       0.665710  NDAR_INVZZNX6W2P
#
# [4453 rows x 3288 columns]

# %%
# save
data_leida_harmonized.to_csv("dataset_leida_harmonized.csv", index=False)

# %%
## FCH harmonization
# imputer model for missing values
imputer = SimpleImputer(strategy="median")

features = imputer.fit_transform(data[harmonics_cols])

# e.g. demo and ethnicity as covariates
covars = data[num_cov_cols + cat_cov_cols + ["batch_id"]]
categorical_cols = cat_cov_cols
continuous_cols = num_cov_cols
batch_col = "batch_id"

# transpose input data
features = features.T

data_combat = nc.neuroCombat(dat=features,
    covars=covars,

    batch_col=batch_col,
    categorical_cols=categorical_cols,
    continuous_cols=continuous_cols,

    eb=False, 
    parametric=True, 
    mean_only=False, 
    ref_batch=None)["data"]

data_fch_harmonized = data_combat.T
data_fch_harmonized
# Out:
# [neuroCombat] Creating design matrix
# [neuroCombat] Standardizing data across features
# [neuroCombat] Fitting L/S model and finding priors
# [neuroCombat] Finding L/S adjustments without Empirical Bayes
# [neuroCombat] Final adjustment of data
# array([[  3.10828575,   3.47949213,   1.91487857, ..., 174.94518843,
#         380.79205114, 232.88218112],
#        [  2.566994  ,   2.79961016,   1.69513899, ..., 204.1863836 ,
#         162.89606975, 349.63603734],
#        [  3.00874646,   2.81261421,   1.64932786, ..., 503.17570037,
#         168.56371282, 580.83242142],
#        ...,
#        [  2.25710731,   3.06832344,   1.40163737, ..., 161.77969363,
#         204.15120959, 335.03666587],
#        [  2.56901513,   2.21384887,   1.49265074, ..., 368.14515546,
#         242.80852945, 323.71314428],
#        [  2.78618955,   2.52338701,   1.95183266, ..., 388.50598368,
#         110.41786337, 243.94520278]])

# %%
np.isnan(data_combat).any()
# Out:
# False

# %%
import pandas as pd

# Create dataframe with names of original columns
data_fch_harmonized = pd.DataFrame(
    data_fch_harmonized,
    columns=harmonics_cols,
    index=data.index
)
data_fch_harmonized["src_subject_id"] = data["src_subject_id"].values
data_fch_harmonized
# Out:
#       Harmonics_power1  Harmonics_power2  Harmonics_power3  Harmonics_power4  \
# 0             3.108286          3.479492          1.914879          1.960069
# 1             2.566994          2.799610          1.695139          2.020614
# 2             3.008746          2.812614          1.649328          1.799771
# 3             2.994816          3.684008          1.933276          1.872740
# 4             2.519016          2.829412          2.041698          2.781701
# ...                ...               ...               ...               ...
# 4448          2.928370          2.740830          1.521654          2.121269
# 4449          2.263671          2.602810          1.913711          1.810228
# 4450          2.257107          3.068323          1.401637          2.707580
# 4451          2.569015          2.213849          1.492651          2.339882
# 4452          2.786190          2.523387          1.951833          1.950568
#
#       Harmonics_power5  Harmonics_power6  Harmonics_power7  Harmonics_power8  \
# 0             1.434098          1.762797          1.400450          1.205757
# 1             1.498308          1.963471          1.392052          1.204367
# 2             1.004009          2.297772          1.188784          1.615318
# 3             1.340740          1.353698          1.299522          1.011449
# 4             1.494378          1.522976          1.447296          1.398948
# ...                ...               ...               ...               ...
# 4448          1.276500          1.812047          1.931804          1.513678
# 4449          1.465550          1.719780          1.817028          1.594127
# 4450          1.328600          1.243200          1.720705          1.328670
# 4451          1.065527          1.627266          1.424724          1.447765
# 4452          1.744132          1.959513          1.217461          1.416349
#
#       Harmonics_power9  Harmonics_power10  ...  Harmonics_energy105  \
# 0             0.937912           1.341020  ...           224.074842
# 1             1.238820           0.905862  ...           265.405805
# 2             1.236740           1.089989  ...           173.462449
# 3             1.452345           0.873378  ...            84.506488
# 4             1.178128           0.889706  ...           183.821034
# ...                ...                ...  ...                  ...
# 4448          1.386830           1.187286  ...           168.604974
# 4449          1.347437           1.311856  ...           183.064944
# 4450          1.311073           1.124740  ...           250.086663
# 4451          1.516035           1.134284  ...           161.322324
# 4452          1.167289           0.800838  ...           141.769055
#
#       Harmonics_energy106  Harmonics_energy107  Harmonics_energy108  \
# 0              270.635802           149.918747           159.906448
# 1              203.827971           526.342366           240.469094
# 2              184.516136           248.086995           230.721626
# 3              155.708194           149.201409           228.160695
# 4              215.331277           110.738939           156.302667
# ...                   ...                  ...                  ...
# 4448           434.276274           126.581943           170.081743
# 4449           237.591258           115.185943           322.262749
# 4450           146.099634           216.054519           180.365018
# 4451           347.493733           113.967876           163.506345
# 4452           304.795849           180.136962           228.697055
#
#       Harmonics_energy109  Harmonics_energy110  Harmonics_energy111  \
# 0              328.380006           187.422646           174.945188
# 1              533.455116           294.448171           204.186384
# 2              224.483155           479.057148           503.175700
# 3              278.510313           227.256269           248.669168
# 4              281.926626           256.659803           197.018614
# ...                   ...                  ...                  ...
# 4448           227.010070           169.987891           303.172569
# 4449           466.824489           238.828473           271.495885
# 4450           321.999509           166.455681           161.779694
# 4451           426.298279           245.146912           368.145155
# 4452           284.642695           449.176537           388.505984
#
#       Harmonics_energy112  Harmonics_energy113    src_subject_id
# 0              380.792051           232.882181  NDAR_INV003RTV85
# 1              162.896070           349.636037  NDAR_INV00BD7VDC
# 2              168.563713           580.832421  NDAR_INV00CY2MDM
# 3              296.606184           605.215230  NDAR_INV00HEV6HB
# 4              183.662900           192.935310  NDAR_INV00LH735Y
# ...                   ...                  ...               ...
# 4448           156.701236           237.394494  NDAR_INVZZ6ZJ2KY
# 4449           748.898893           137.803381  NDAR_INVZZ81LEEV
# 4450           204.151210           335.036666  NDAR_INVZZJ3A7BK
# 4451           242.808529           323.713144  NDAR_INVZZLZCKAY
# 4452           110.417863           243.945203  NDAR_INVZZNX6W2P
#
# [4453 rows x 227 columns]

# %%
# save
data_fch_harmonized.to_csv("dataset_fch_harmonized.csv", index=False)
